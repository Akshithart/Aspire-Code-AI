# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshithart/Aspire-Code-AI/blob/main/aspire_task_6_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INSTALL LIBRARIES

# %%
# !pip install -q transformers accelerate gradio

# %% [markdown]
# CONFIGURATION SECTIONS

# %%
MODEL_NAME="deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"
TEMPERATURE=1.5
MAX_TOKENS=200

# %% [markdown]
# LOAD MODEL

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model=MODEL_NAME,
    device_map="auto",
    trust_remote_code=True
)

print("Model Loaded Successfully")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/679 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.07k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Model Loaded Successfully

# %% [markdown]
# GENERATION FUNCTION

# %%
def generate_response(prompt):
    # Cricket-related keywords
    cricket_keywords = [
        "cricket", "batting", "bowling", "fielding", "wicket",
        "batsman", "bowler", "spin", "googly", "yorker", "cover drive",
        "leg spin", "off spin", "umpire", "run out", "stump"
    ]

    # Check if prompt is cricket-related
    if not any(word.lower() in prompt.lower() for word in cricket_keywords):
        return "⚠️ I am a Cricket Coach. I only answer cricket-related questions."

    messages = [
        {"role": "system", "content": "You are a professional cricket coach. Only answer cricket-related queries."},
        {"role": "user", "content": prompt}
    ]

    try:
        text = generator.tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True
        )
    except Exception:
        text = prompt

    output = generator(
        text,
        max_new_tokens=MAX_TOKENS,
        temperature=TEMPERATURE,
        do_sample=True,
        return_full_text=False
    )

    return output[0]["generated_text"]

# %% [markdown]
# TEST PROMPT

# %%
reply = generate_response("Suggest batting drills for beginners")
print("Cricket Coach:", reply)
# Out:
# [transformers] Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Cricket Coach: Okay, so I'm trying to set up some batting drills as a cricket coach for my new students. I'm just starting out, so I need to figure out the best way to do this without overwhelming them. Let me think about how to approach this step by step.
#
# First, I need to understand the basics. Batting drills should build their skill gradually without making them lose interest once they get a bit better. They need to be specific and consistent so they can follow along easily.
#
# What should the first drill be? I remember someone mentioned the 20 over swing. It seems solid. I can explain to them the different terms they'll need to remember like crease, slip, outside fly ball, etc. Maybe using examples will help them better understand the cues.
#
# Next, I should maybe cover the 5th and 7th wickets cover. I've seen diagrams before where you miss two batsmen to cover. This way, if the game changes mid-wicket, they

# %% [markdown]
# GRADIO INTERFACE

# %%
import gradio as gr

with gr.Blocks(theme=gr.themes.Soft()) as demo:

    gr.Markdown("# 🏏 Cricket Coach - Powered by DeepSeek")

    prompt = gr.Textbox(
        label="Ask your Cricket Coach",
        lines=6,
        placeholder="e.g., How to improve against spin bowling?"
    )

    btn = gr.Button("🚀 Get Coaching Advice")

    output = gr.Textbox(
        label="Coach Response",
        lines=12
    )

    btn.click(
        fn=generate_response,  # your DeepSeek function
        inputs=prompt,
        outputs=output
    )

demo.launch(share=True)
# Out:
# /tmp/ipykernel_1196/608643498.py:3: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft()) as demo:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ba8cd5142defc40a32.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ba8cd5142defc40a32.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
